# %% [markdown]
# # Naive Bayes
#
# 1. Naive Bayes is a machine learning classification algorithm that predicts the category of a data point using probability.
# 2. It assumes that all features are independent of each other

# %%
import numpy as np
a = np.array([1,2,3])
b = np.array([4,5,6])
a + b
# Out:
# array([5, 7, 9])

# %%
a = np.array([[1,2,3],
              [4,5,6]])
a + np.array([10,20,30])
# Out:
# array([[11, 22, 33],
#        [14, 25, 36]])
